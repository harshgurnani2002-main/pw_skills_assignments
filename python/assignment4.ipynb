# %% [markdown]
# # Assignment -python oops

# %%
# question1 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
    def speak(self)->None:
        print("the animal makes a sound")

class Dog(Animal):
    def speak(self)->None:
        print("Bark")

mydog=Dog()
mydog.speak()
# Out:
# Bark

# %%
#question 2 write a program to create an abstract class shape with method area derrives classes circle rectangle from it and implement the area method for both classes
from abc import ABC,abstractmethod
import math
class Shape(ABC):
    @abstractmethod
    def area(self)->float:
        pass

class Circle(Shape):
    def __init__(self, radius: float):
        self.radius = radius

    def area(self)->float:
        return math.pi * self.radius**2

class Rectangle(Shape):
    def __init__(self, width: float, height: float):
        self.width = width
        self.height = height

    def area(self)->float:
        return self.width * self.height
circle=Circle(5)
rectangle=Rectangle(4,6)
print(f"area of circle: {circle.area()}")
print(f"area of rectangle: {rectangle.area()}")
# Out:
# area of circle: 78.53981633974483
# area of rectangle: 24

# %%
# question 3 . Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
class Vehicle:
    def __init__(self, type: str):
        self.type = type

class Car(Vehicle):
    def __init__(self, make: str, model: str):
        super().__init__("Car")
        self.make = make
        self.model = model

class ElectricCar(Car):
    def __init__(self, make: str, model: str, battery_capacity: float):
        super().__init__(make, model)
        self.battery_capacity = battery_capacity
my_electric_car = ElectricCar("Tata", "nexon", 100)

print(f"Type: {my_electric_car.type}, Make: {my_electric_car.make}, Model: {my_electric_car.model}, Battery Capacity: {my_electric_car.battery_capacity} kWh")
# Out:
# Type: Car, Make: Tata, Model: nexon, Battery Capacity: 100 kWh

# %%
#question 4 demonstrate polymorphism by creating a base class bird with a method fly(). Create two derived classes sparrow and penguin that implement the fly() method differently.
class Bird:
    def fly(self)->None:
        print("the bird is flying")

class Sparrow(Bird):
    def fly(self)->None:
        print("the sparrow flies at a low altitude")

class Penguin(Bird):
    def fly(self)->None:
        print("Penguins can't fly due to their body structure")

sparrow=Sparrow()
penguin=Penguin()
sparrow.fly()
penguin.fly()
# Out:
# the sparrow flies at a low altitude
# Penguins can't fly due to their body structure

# %%
#question 5 write a program to demonstrate encapsulation by creating a bank account with private attributes balance and methods to deposit withdraw and check balance
class BankAccount:
    def __init__(self, initial_balance: float):
        self.__balance = initial_balance

    def deposit(self, amount: float) -> None:
        if amount > 0:
            self.__balance += amount
        else:
            print("invalid deposit amount")

    def withdraw(self, amount: float) -> None:
        if 0 < amount <= self.__balance:
            self.__balance -= amount
        else:
            print("invalid withdrawal amount")

    def get_balance(self) -> float:
        return self.__balance
account = BankAccount(1000)
account.deposit(500)
account.withdraw(200)
print(f"current balance amount : {account.get_balance()}")
# Out:
# current balance amount : 1300

# %%
#question 6 demonstrate runtime polymorphism by using a method play() in a base class instrument and overriding it in derived classes guitar and piano

class Instrument:
    def play(self)->None:
        print("the instrument is being played")

class Guitar(Instrument):
    def play(self)->None:
        print("the guitar is playing")

class Piano(Instrument):
    def play(self)->None:
        print("the piano is playing")

def playing_instrument(instrument: Instrument) -> None:
    instrument.play()

guitar = Guitar()
piano = Piano()

playing_instrument(guitar)
playing_instrument(piano)
# Out:
# the guitar is playing
# the piano is playing

# %%
#question 7 create a class mathoperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers
class MathOperations:
    @classmethod
    def add_numbers(cls, a: float, b: float) -> float:
        return a + b

    @staticmethod
    def subtract_numbers(a: float, b: float) -> float:
        return a - b
# Using the class method
sum_result = MathOperations.add_numbers(10, 5)
print(f"sum: {sum_result}")

# Using the static method
difference_result = MathOperations.subtract_numbers(10, 5)
print(f"difference: {difference_result}")
# Out:
# sum: 15
# difference: 5

# %%
#question8 implement a class person with a class method count the total number of person created
class Person:
    total_persons = 0

    def __init__(self, name: str):
        self.name = name
        Person.total_persons += 1

    @classmethod
    def count_persons(cls) -> int:
        return cls.total_persons

person1 = Person("harsh")
person2 = Person("arjun")
person3 = Person("parth")
print(f"total number of persons created: {Person.count_persons()}")
# Out:
# total number of persons created: 3

# %%
#quesiton 9 write a class function with attributes numerator and denominator override the str method to display the fraction as "numerator/denominator"
class Fraction:
    def __init__(self, numerator: int, denominator: int):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self) -> str:
        return f"{self.numerator}/{self.denominator}"
fraction = Fraction(3, 4)
print(f"fraction: {fraction}")
# Out:
# fraction: 3/4

# %%
#quesiton 10 demonstrate operator overloading by creating a class vector and overloading the add method to add two vectors
class Vector:
    def __init__(self, x: float, y: float):
        self.x = x
        self.y = y

    def __add__(self, other: "Vector") -> "Vector":
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        return NotImplemented

vector1 = Vector(2, 3)
vector2 = Vector(4, 5)
result = vector1 + vector2
print(f"output  vector: ({result.x}, {result.y})")
# Out:
# output  vector: (6, 8)

# %%
#question11 create a class person with attributes name and age . add a moethod greeet() that prints 'hello my name is {name} and i am {age} years old'

class Person:
    def __init__(self, name: str, age: int):
        self.name = name
        self.age = age

    def greet(self)->None:
        print(f"hello my name is {self.name} and i am {self.age} years old")
person = Person("Harsh Gurnani", 23)
person.greet()
# Out:
# hello my name is Harsh Gurnani and i am 23 years old

# %%
#question 12 implement a class student with attributes name and grades .create a method average_grade() to compute average of grades .

class Student:
    def __init__(self,name:str,grades:list):
        self.name=name
        self.grades=grades
    def average_grade(self)->float:
        return sum(self.grades)/len(self.grades)

student=Student("Harsh",[85,90,78,92,88])
print(f"average grade of {student.name} is {student.average_grade()}")
# Out:
# average grade of Harsh is 86.6

# %%
#question 13 create a class reactangle with methods set_dimensions() to set the dimentsions and area() to calculate area of rectangle
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0
    def set_dimensions(self, length: float, width: float) -> None:
        self.length = length
        self.width = width
    def area(self) -> float:
        return self.length * self.width

rectangle = Rectangle()
rectangle.set_dimensions(5, 3)
print(f"area of rectangle: {rectangle.area()}")
# Out:
# area of rectangle: 15

# %%
#Question 14 create a class Employee with method calculate_salary() that computes the salary based on hours worked and hourly rate create a derrrived class manager that adds bonus to the salary

class Employee:
    def __init__(self, name: str, hourly_rate: float):
        self.name = name
        self.hourly_rate = hourly_rate

    def calculate_salary(self, hours_worked: float) -> float:
        return self.hourly_rate * hours_worked

class Manager(Employee):
    def __init__(self, name: str, hourly_rate: float, bonus: float):
        super().__init__(name, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self, hours_worked: float) -> float:
        base_salary = super().calculate_salary(hours_worked)
        return base_salary + self.bonus
manager = Manager("harsh", 50, 500)
total_salary = manager.calculate_salary(160)
print(f"total salary of {manager.name} is {total_salary}")
# Out:
# total salary of harsh is 8500

# %%
#question 15 create a class product with attributes name,price and quantity . implement a mothod total_price() that calculates total price of the product

class Product:
    def __init__(self, name: str, price: float, quantity: int):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self) -> float:
        return self.price * self.quantity

product1= Product("book", 15.99, 3)
print(f"total price of {product1.name} is {product1.total_price()}")
# Out:
# total price of book is 47.97

# %%
# question 16 create a class animal with an abstract method sound() . create two derrived classes cow and sheep that implement the sound() method
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self)->None:
        pass
class Cow(Animal):
    def sound(self)->None:
        print("moo")
class Sheep(Animal):
    def sound(self)->None:
        print("baa")

mycow=Cow()
mysheep=Sheep()
mycow.sound()
mysheep.sound()
# Out:
# moo
# baa

# %%
# question 17 create a class book with attributes title author and year_published . add a mothod get_book_info() that returns a formatted string with book details

class Book:
    def __init__(self, title: str, author: str, year_published: int):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self) -> str:
        return f"'{self.title}' by {self.author}, published in {self.year_published}"
book1 = Book("introduction to python", "harsh", 2010)

# %%
# question 18 create a class house with attributes adress and price . create a derrived class mansion that adds an attribute number_of_rooms

class House:
    def __init__(self,address:str,price:float):
        self.address=address
        self.price=price
class Mansion(House):
    def __init__(self,address:str,price:float,number_of_rooms:int):
        super().__init__(address,price)
        self.number_of_rooms=number_of_rooms
mansion1=Mansion("123 luxury st",1000000,10)
print(f"mansion address: {mansion1.address}, price: {mansion1.price}, number of rooms: {mansion1.number_of_rooms}")
