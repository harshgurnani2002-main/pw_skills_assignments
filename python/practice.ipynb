# %%
# ask a user for number if user dosent enter a number then handle the exception and print an error message

try:
    num=float(input("enter a number"))
    print(f"you entered number : {num}")
except ValueError:
    print("error : invalid input , please enter a valid number")
